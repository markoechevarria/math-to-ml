# %%
import pandas as pd

# Print the version
print(f"pandas version: {pd.__version__}")
# Out:
# pandas version: 3.0.1

# %% [markdown]
# ### 1. Datatypes

# %%
# Creating a series of car types
cars = pd.Series(["BMW", "Toyota", "Honda"])
cars
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: str

# %%
colours = pd.Series(["Blue", "Red", "White"])
colours
# Out:
# 0     Blue
# 1      Red
# 2    White
# dtype: str

# %%
# Creating a DataFrame of cars and colours
car_data = pd.DataFrame({"Car type": cars, 
                         "Colour": colours})
car_data
# Out:
#   Car type Colour
# 0      BMW   Blue
# 1   Toyota    Red
# 2    Honda  White

# %% [markdown]
# ### 2. Importing data¶

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales.csv")
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ### 3. Exporting data¶

# %%
df.to_csv("data/exported-car-sales.csv")

# %% [markdown]
# ### 4. Describing data¶

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.dtypes
# Out:
# Make               str
# Colour             str
# Odometer (KM)    int64
# Doors            int64
# Price              str
# dtype: object

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     str
#  1   Colour         10 non-null     str
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     str
# dtypes: int64(2), str(3)
# memory usage: 532.0 bytes

# %%
# Calling .mean() on a DataFrame
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
# Calling .mean() on a Series
car_prices = pd.Series([3000, 3500, 11250])
car_prices.mean()
# Out:
# np.float64(5916.666666666667)

# %%
# Calling .sum() on a DataFrame with numeric_only=False (default)
car_sales.sum(numeric_only=False)
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales.columns[0]
# Out:
# 'Make'

# %% [markdown]
# ### 5. Viewing and selecting data

# %%
# Show the first 5 rows of car_sales
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# Show the first 7 rows of car_sales
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
# Create a sample series
animals = pd.Series(["cat", "dog", "bird", "snake", "ox", "lion"], 
                    index=[0, 3, 9, 8, 67, 3])
animals
# Out:
# 0       cat
# 3       dog
# 9      bird
# 8     snake
# 67       ox
# 3      lion
# dtype: str

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# Get all rows of the "Colour" column
car_sales.loc[:, "Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: str

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
# Select cars which are made by Toyota
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
# Compare car Make with number of Doors
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Group by the Make column and find the mean of the other columns 
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# Import matplotlib and tell Jupyter to show plots
import matplotlib.pyplot as plt
# %matplotlib inline

car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales.plot(x="Make", y="Odometer (KM)");

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"] = car_sales["Price"].replace('[$,.]', '', regex=True).astype(int)

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %% [markdown]
# ### 6. Manipulating data¶

# %%
# Lower the Make column
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: str

# %%
# Set Make column to be lowered
car_sales["Make"] = car_sales["Make"].str.lower()
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000

# %%
car_sales_missing = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# Fill Odometer column missing values with mean
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean() )
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
# Remove missing data
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
# Create a column from a Python list
engine_sizes = [1.3, 2.0, 3.0, 4.2, 1.6, 1, 2.0, 2.3, 2.0, 3.0]
car_sales["Engine Size"] = engine_sizes
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Engine Size
# 0  toyota  White         150043      4   400000          1.3
# 1   honda    Red          87899      4   500000          2.0
# 2  toyota   Blue          32549      3   700000          3.0
# 3     bmw  Black          11179      5  2200000          4.2
# 4  nissan  White         213095      4   350000          1.6
# 5  toyota  Green          99213      4   450000          1.0
# 6   honda   Blue          45698      4   750000          2.0
# 7   honda   Blue          54738      4   700000          2.3
# 8  toyota  White          60000      4   625000          2.0
# 9  nissan  White          31600      4   970000          3.0

# %%
# Column from other columns
car_sales["Price per KM"] = car_sales["Price"] / car_sales["Odometer (KM)"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Engine Size  Price per KM
# 0  toyota  White         150043      4   400000          1.3      2.665902
# 1   honda    Red          87899      4   500000          2.0      5.688347
# 2  toyota   Blue          32549      3   700000          3.0     21.506037
# 3     bmw  Black          11179      5  2200000          4.2    196.797567
# 4  nissan  White         213095      4   350000          1.6      1.642460
# 5  toyota  Green          99213      4   450000          1.0      4.535696
# 6   honda   Blue          45698      4   750000          2.0     16.412097
# 7   honda   Blue          54738      4   700000          2.3     12.788191
# 8  toyota  White          60000      4   625000          2.0     10.416667
# 9  nissan  White          31600      4   970000          3.0     30.696203

# %%
car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Engine Size  Price per KM  \
# 0  toyota  White         150043      4   400000          1.3      2.665902
# 1   honda    Red          87899      4   500000          2.0      5.688347
# 2  toyota   Blue          32549      3   700000          3.0     21.506037
# 3     bmw  Black          11179      5  2200000          4.2    196.797567
# 4  nissan  White         213095      4   350000          1.6      1.642460
# 5  toyota  Green          99213      4   450000          1.0      4.535696
# 6   honda   Blue          45698      4   750000          2.0     16.412097
# 7   honda   Blue          54738      4   700000          2.3     12.788191
# 8  toyota  White          60000      4   625000          2.0     10.416667
# 9  nissan  White          31600      4   970000          3.0     30.696203
#
#    Number of wheels
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# 5                 4
# 6                 4
# 7                 4
# 8                 4
# 9                 4

# %%
car_sales["Passed road safety"] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Engine Size  Price per KM  \
# 0  toyota  White         150043      4   400000          1.3      2.665902
# 1   honda    Red          87899      4   500000          2.0      5.688347
# 2  toyota   Blue          32549      3   700000          3.0     21.506037
# 3     bmw  Black          11179      5  2200000          4.2    196.797567
# 4  nissan  White         213095      4   350000          1.6      1.642460
# 5  toyota  Green          99213      4   450000          1.0      4.535696
# 6   honda   Blue          45698      4   750000          2.0     16.412097
# 7   honda   Blue          54738      4   700000          2.3     12.788191
# 8  toyota  White          60000      4   625000          2.0     10.416667
# 9  nissan  White          31600      4   970000          3.0     30.696203
#
#    Number of wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# 4                 4                True
# 5                 4                True
# 6                 4                True
# 7                 4                True
# 8                 4                True
# 9                 4                True

# %%
# Drop the Price per KM column
car_sales = car_sales.drop("Price per KM", axis=1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Engine Size  \
# 0  toyota  White         150043      4   400000          1.3
# 1   honda    Red          87899      4   500000          2.0
# 2  toyota   Blue          32549      3   700000          3.0
# 3     bmw  Black          11179      5  2200000          4.2
# 4  nissan  White         213095      4   350000          1.6
# 5  toyota  Green          99213      4   450000          1.0
# 6   honda   Blue          45698      4   750000          2.0
# 7   honda   Blue          54738      4   700000          2.3
# 8  toyota  White          60000      4   625000          2.0
# 9  nissan  White          31600      4   970000          3.0
#
#    Number of wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# 4                 4                True
# 5                 4                True
# 6                 4                True
# 7                 4                True
# 8                 4                True
# 9                 4                True

# %%
# Sample car_sales
car_sales_sampled = car_sales.sample(frac=1)
car_sales_sampled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Engine Size  \
# 5  toyota  Green          99213      4   450000          1.0
# 1   honda    Red          87899      4   500000          2.0
# 7   honda   Blue          54738      4   700000          2.3
# 8  toyota  White          60000      4   625000          2.0
# 6   honda   Blue          45698      4   750000          2.0
# 4  nissan  White         213095      4   350000          1.6
# 0  toyota  White         150043      4   400000          1.3
# 3     bmw  Black          11179      5  2200000          4.2
# 2  toyota   Blue          32549      3   700000          3.0
# 9  nissan  White          31600      4   970000          3.0
#
#    Number of wheels  Passed road safety
# 5                 4                True
# 1                 4                True
# 7                 4                True
# 8                 4                True
# 6                 4                True
# 4                 4                True
# 0                 4                True
# 3                 4                True
# 2                 4                True
# 9                 4                True

# %%
car_sales_sampled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Engine Size  \
# 0      5  toyota  Green          99213      4   450000          1.0
# 1      1   honda    Red          87899      4   500000          2.0
# 2      7   honda   Blue          54738      4   700000          2.3
# 3      8  toyota  White          60000      4   625000          2.0
# 4      6   honda   Blue          45698      4   750000          2.0
# 5      4  nissan  White         213095      4   350000          1.6
# 6      0  toyota  White         150043      4   400000          1.3
# 7      3     bmw  Black          11179      5  2200000          4.2
# 8      2  toyota   Blue          32549      3   700000          3.0
# 9      9  nissan  White          31600      4   970000          3.0
#
#    Number of wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# 4                 4                True
# 5                 4                True
# 6                 4                True
# 7                 4                True
# 8                 4                True
# 9                 4                True

# %%
car_sales["Odometer (KM)"].apply(lambda x: x / 1.6)
# Out:
# 0     93776.875
# 1     54936.875
# 2     20343.125
# 3      6986.875
# 4    133184.375
# 5     62008.125
# 6     28561.250
# 7     34211.250
# 8     37500.000
# 9     19750.000
# Name: Odometer (KM), dtype: float64
